# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Goal (for now):
# Given a single row, representing a single service, predict whether or not that patient will end up requiring inpatient services in the next 18 months (540 days)
#
# Constructing the outcome will require a sliding window over the entire dataframe
#
# If svc_period is > 0, then the patient has attended inpatient services
#
# In this case, any service row for that patient that has a svc_start > (svc_start of inpatient - 18*30 days) will be flagged as positive
# Any rows indicating inpatient procedures can be removed from the dataset (in this case since is is directing the outcome)
#
# Would be better to find architectures that make use of multiple rows, and can find patterns in pre-inpatient visits across different patients who end up eventually getting admitted

# %%
data = pd.read_csv('data/anon_claims_data_traindev_15to22.csv')

# %%
data.head(n=10)
# Out:
#    Unnamed: 0  FNAME  LNAME  SERVICE_RENDERED_ROW_ID  MCI_UNIQ_ID  DOB   RACE  \
# 0           0    NaN    NaN                      NaN          NaN  NaN  White
# 1          12    NaN    NaN                      NaN          NaN  NaN  Black
# 2          13    NaN    NaN                      NaN          NaN  NaN  Black
# 3          14    NaN    NaN                      NaN          NaN  NaN  Black
# 4          15    NaN    NaN                      NaN          NaN  NaN  Black
# 5          16    NaN    NaN                      NaN          NaN  NaN  Black
# 6          17    NaN    NaN                      NaN          NaN  NaN  Black
# 7          18    NaN    NaN                      NaN          NaN  NaN  Black
# 8          19    NaN    NaN                      NaN          NaN  NaN  Black
# 9          20    NaN    NaN                      NaN          NaN  NaN  Black
#
#    GENDER  AGE AGE_GROUP  ... DIAGNOSIS_COMMON_SORT             DIAGNOSIS_CAT  \
# 0  Female   62     45-64  ...           Bipolar D/O          Bipolar Disorder
# 1    Male   56     45-64  ...        Org Mental D/O  Organic Mental Disorders
# 2    Male   56     45-64  ...        Org Mental D/O  Organic Mental Disorders
# 3    Male   56     45-64  ...        Org Mental D/O  Organic Mental Disorders
# 4    Male   56     45-64  ...        Org Mental D/O  Organic Mental Disorders
# 5    Male   57     45-64  ...        Org Mental D/O  Organic Mental Disorders
# 6    Male   57     45-64  ...        Org Mental D/O  Organic Mental Disorders
# 7    Male   57     45-64  ...        Org Mental D/O  Organic Mental Disorders
# 8    Male   54     45-64  ...        Depressive D/O          Major Depression
# 9    Male   54     45-64  ...        Org Mental D/O  Organic Mental Disorders
#
#   SVC1ST SERVICE_SEQ   svc_start     svc_end                 svc_period  \
# 0    NaN         NaN  2021-01-21  2021-01-21  0 days 00:00:00.000000000
# 1    NaN         NaN  2019-08-02  2019-08-02  0 days 00:00:00.000000000
# 2    NaN         NaN  2019-09-16  2019-09-16  0 days 00:00:00.000000000
# 3    NaN         NaN  2019-11-08  2019-11-08  0 days 00:00:00.000000000
# 4    NaN         NaN  2019-12-13  2019-12-13  0 days 00:00:00.000000000
# 5    NaN         NaN  2020-01-13  2020-01-13  0 days 00:00:00.000000000
# 6    NaN         NaN  2020-02-14  2020-02-14  0 days 00:00:00.000000000
# 7    NaN         NaN  2020-03-11  2020-03-11  0 days 00:00:00.000000000
# 8    NaN         NaN  2017-05-22  2017-05-22  0 days 00:00:00.000000000
# 9    NaN         NaN  2017-09-18  2017-09-18  0 days 00:00:00.000000000
#
#      set mci_anon svc_id_anon
# 0    dev        0           0
# 1  train        2          12
# 2  train        2          13
# 3  train        2          14
# 4  train        2          15
# 5  train        2          16
# 6  train        2          17
# 7  train        2          18
# 8  train        2          19
# 9  train        2          20
#
# [10 rows x 36 columns]

# %%
# Drop first column (old index)
data.drop(columns=['Unnamed: 0'])

# Change svc start and end to datetime
data['svc_start'] = pd.to_datetime(data['svc_start'])
data['svc_end'] = pd.to_datetime(data['svc_end'])

# Change svc_period to a timedelta of days
data['svc_period'] = data['svc_period'].apply(lambda x: pd.Timedelta(days = int(x.split(' ')[0])))

# For efficiency purposes, we change svc_period to an interger representing days instead of an actual pd.Timedelta object
# If needed, this will be used to create an actual Timedelta object to perform operations on other columns, this is not needed for most rows

# %%
def drop_null_cols(df: pd.DataFrame) -> pd.DataFrame:

    dropcols = [col for col in df.columns if df[col].notna().sum() == 0]

    return df.drop(columns=dropcols)


data = drop_null_cols(data)

# %%
test = data.loc[data['mci_anon']==2]

test['svc_period'].max()
# Out:
# Timedelta('0 days 00:00:00')

# %% [markdown]
# User service category:
# inpatient mental health
# pshycheatric inpatien hospital
# IP-MH
#
# if they have any row in the services table that has one of those categories then that row is considered inpatient services
#
# service category also has crisis: MH-CRISIS-OUTCOME variable, can be second label that can be predicted on

# %%
def construct_outcome(
    df: pd.DataFrame, window: pd.Timedelta = pd.Timedelta(days=540)
) -> pd.DataFrame:
    """ """

    # Initialize outcome column
    df["outcome"] = 0

    null_period = pd.Timedelta(days=0)

    for idx, mci_group in df.groupby(by="mci_anon"):
        if mci_group["svc_period"].max() != null_period:
            crit_period_cutoff = (
                mci_group["svc_start"].loc[mci_group["svc_period"] != null_period].min()
                - window
            )

            df["outcome"].iloc[(mci_group["svc_start"] >= crit_period_cutoff).index] = 1

    return df

# %%
data = construct_outcome(data)
# Out:
# /var/folders/rl/dnlq62k50fd_dd8959xr62nh0000gn/T/ipykernel_77751/198255421.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['outcome'].iloc[(mci_group['svc_start']>=crit_period_cutoff).index] = 1

# %%
data.loc[data['outcome']==1]
# Out:
#          Unnamed: 0   RACE  GENDER  AGE AGE_GROUP             SVC_START_DT  \
# 38               53  Black  Female   29     21-44  2021-06-01 00:00:00.000
# 39               54  Black  Female   29     21-44  2021-10-01 00:00:00.000
# 108             229  Black    Male   56     45-64  2020-07-03 00:00:00.000
# 109             230  Black    Male   56     45-64  2020-07-08 00:00:00.000
# 110             231  Black    Male   56     45-64  2020-07-09 00:00:00.000
# ...             ...    ...     ...  ...       ...                      ...
# 1669708     2909956  White  Female   53     45-64  2015-10-07 00:00:00.000
# 1669710     2909960  White  Female   54     45-64  2016-05-09 00:00:00.000
# 1669712     2909978  White  Female   52     45-64  2017-05-30 00:00:00.000
# 1669713     2909981  White  Female   21     21-44  2022-05-11 00:00:00.000
# 1669714     2909983  White  Female   36     21-44  2019-05-08 00:00:00.000
#
#                       SVC_END_DT FISCAL_YEAR FISCAL_QUARTER   PAYER  ...  \
# 38       2021-06-30 00:00:00.000     FY20/21             Q4    CCBH  ...
# 39       2021-10-31 00:00:00.000     FY21/22             Q2    CCBH  ...
# 108      2020-07-03 00:00:00.000     FY20/21             Q1    CCBH  ...
# 109      2020-07-08 00:00:00.000     FY20/21             Q1    CCBH  ...
# 110      2020-07-09 00:00:00.000     FY20/21             Q1    CCBH  ...
# ...                          ...         ...            ...     ...  ...
# 1669708  2015-10-07 00:00:00.000     FY15/16             Q2    CCBH  ...
# 1669710  2016-05-09 00:00:00.000     FY15/16             Q4  COUNTY  ...
# 1669712  2017-05-30 00:00:00.000     FY16/17             Q4  COUNTY  ...
# 1669713  2022-05-11 00:00:00.000     FY21/22             Q4    CCBH  ...
# 1669714  2019-05-08 00:00:00.000     FY18/19             Q4    CCBH  ...
#
#                                             DIAGNOSIS_DESC  \
# 38                      Cannabis dependence, uncomplicated
# 39                           Cannabis abuse, uncomplicated
# 108                          Bipolar disorder, unspecified
# 109                          Bipolar disorder, unspecified
# 110                          Bipolar disorder, unspecified
# ...                                                    ...
# 1669708             Schizoaffective disorder, bipolar type
# 1669710             Schizoaffective disorder, bipolar type
# 1669712  Bipolar disord, crnt episode manic w/o psych f...
# 1669713                                Bipolar II disorder
# 1669714  Bipolar disord, crnt epsd depress, sev, w/o ps...
#
#         DIAGNOSIS_COMMON_SORT              DIAGNOSIS_CAT  svc_start  \
# 38                   Cannabis      Cannabis Use Disorder 2021-06-01
# 39                   Cannabis      Cannabis Use Disorder 2021-10-01
# 108               Bipolar D/O           Bipolar Disorder 2020-07-03
# 109               Bipolar D/O           Bipolar Disorder 2020-07-08
# 110               Bipolar D/O           Bipolar Disorder 2020-07-09
# ...                       ...                        ...        ...
# 1669708         Schizophrenia  Schizoaffective Disorders 2015-10-07
# 1669710         Schizophrenia  Schizoaffective Disorders 2016-05-09
# 1669712           Bipolar D/O           Bipolar Disorder 2017-05-30
# 1669713           Bipolar D/O           Bipolar Disorder 2022-05-11
# 1669714           Bipolar D/O           Bipolar Disorder 2019-05-08
#
#            svc_end svc_period    set  mci_anon svc_id_anon outcome
# 38      2021-06-30    29 days    dev         6          53       1
# 39      2021-10-31    30 days    dev         6          54       1
# 108     2020-07-03     0 days    dev        23         229       1
# 109     2020-07-08     0 days    dev        23         230       1
# 110     2020-07-09     0 days    dev        23         231       1
# ...            ...        ...    ...       ...         ...     ...
# 1669708 2015-10-07     0 days  train     70807     2909956       1
# 1669710 2016-05-09     0 days  train     70807     2909960       1
# 1669712 2017-05-30     0 days  train     58587     2909978       1
# 1669713 2022-05-11     0 days  train     80968     2909981       1
# 1669714 2019-05-08     0 days    dev     83115     2909983       1
#
# [573354 rows x 30 columns]

# %%
print(data['mci_anon'].loc[data['outcome']==1].unique())
# Out:
# 9286

# %%
data.loc[data['mci_anon']==83115]
# Out:
#          Unnamed: 0   RACE  GENDER  AGE AGE_GROUP             SVC_START_DT  \
# 589871       870113  White  Female   36     21-44  2019-06-12 00:00:00.000
# 693900      1117023  White  Female   33     21-44  2016-02-24 00:00:00.000
# 717698      1173280  White  Female   36     21-44  2019-07-10 00:00:00.000
# 769223      1296304  White  Female   37     21-44  2020-11-01 00:00:00.000
# 792888      1352318  White  Female   33     21-44  2016-08-22 00:00:00.000
# 792892      1352331  White  Female   38     21-44  2021-04-01 00:00:00.000
# 807008      1385729  White  Female   37     21-44  2020-06-01 00:00:00.000
# 1401151     2270210  White  Female   33     21-44  2016-06-01 00:00:00.000
# 1424576     2326230  White  Female   34     21-44  2017-06-26 00:00:00.000
# 1429323     2337483  White  Female   34     21-44  2017-05-03 00:00:00.000
# 1429324     2337484  White  Female   34     21-44  2017-05-12 00:00:00.000
# 1433994     2348807  White  Female   34     21-44  2017-05-10 00:00:00.000
